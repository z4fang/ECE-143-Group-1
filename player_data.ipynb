# %%
# importing library and read in data
import pandas as pd

player15 = pd.read_csv('Data/player/players_15.csv');
# Out:
# C:\Users\kenfa\AppData\Local\Temp\ipykernel_34716\3183781485.py:4: DtypeWarning: Columns (104) have mixed types. Specify dtype option on import or set low_memory=False.
#   player15 = pd.read_csv('Data/player/players_15.csv');

# %%
# player15 = player15.drop(labels=['player_face_url', 'club_logo_url', 'club_flag_url', 'nation_logo_url', 'nation_flag_url',
#                                   'rb', 'gk','rcb','cb','lcb','lb','rwb','rdm','cdm','ldm','lwb', 'rm', 'rcm','cm','lcm',
#                                   'lm', 'ram', 'cam', 'lam', 'rw', 'rf', 'cf', 'lf', 'lw', 'rs', 'st', 'ls', ''], axis=1);

player15 = player15[['sofifa_id','short_name','short_name','long_name', 'value_eur', 'wage_eur', 'age', 'height_cm', 
                     'weight_kg','club_team_id', 'club_name','nationality_id', 'nationality_name']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 5
#       1 # player15 = player15.drop(labels=['player_face_url', 'club_logo_url', 'club_flag_url', 'nation_logo_url', 'nation_flag_url',
#       2 #                                   'rb', 'gk','rcb','cb','lcb','lb','rwb','rdm','cdm','ldm','lwb', 'rm', 'rcm','cm','lcm',
#       3 #                                   'lm', 'ram', 'cam', 'lam', 'rw', 'rf', 'cf', 'lf', 'lw', 'rs', 'st', 'ls', ''], axis=1);
# ----> 5 player15 = player15[['sofifaid','short_name','short_name','long_name', 'value_eur', 'wage_eur', 'age', 'height_cm',
#       6                      'weight_kg','club_team', 'club_name','nationality_id', 'nationality_name']]
#
# File c:\Users\kenfa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\kenfa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File c:\Users\kenfa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['sofifaid', 'club_team'] not in index"

# %%
player15.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini               CF
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           LW, LM
# 2          A. Robben                         Arjen Robben       RM, LM, RW
# 3     Z. Ibrahimović                   Zlatan Ibrahimović               ST
# 4           M. Neuer                   Manuel Peter Neuer               GK
#
#    overall  potential    value_eur  wage_eur  age  ... mentality_composure  \
# 0       93         95  100500000.0  550000.0   27  ...                 NaN
# 1       92         92   79000000.0  375000.0   29  ...                 NaN
# 2       90         90   54500000.0  275000.0   30  ...                 NaN
# 3       90         90   52500000.0  275000.0   32  ...                 NaN
# 4       90         90   63500000.0  300000.0   28  ...                 NaN
#
#    defending_marking_awareness  defending_standing_tackle  \
# 0                           25                         21
# 1                           22                         31
# 2                           29                         26
# 3                           25                         41
# 4                           25                         25
#
#    defending_sliding_tackle goalkeeping_diving goalkeeping_handling  \
# 0                        20                  6                   11
# 1                        23                  7                   11
# 2                        26                 10                    8
# 3                        27                 13                   15
# 4                        25                 87                   85
#
#    goalkeeping_kicking goalkeeping_positioning  goalkeeping_reflexes  \
# 0                   15                      14                     8
# 1                   15                      14                    11
# 2                   11                       5                    15
# 3                   10                       9                    12
# 4                   92                      90                    86
#
#   goalkeeping_speed
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4              60.0
#
# [5 rows x 78 columns]
